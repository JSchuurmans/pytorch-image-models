# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os

def select_hardware(
    cuda: str = None,
    cpu: str = None,
) -> None:
    os.environ['CUDA_DEVICE_ORDER'] = 'PCI_BUS_ID'

    if cuda is not None:
        os.environ['CUDA_VISIBLE_DEVICES'] = cuda

    if cpu is not None:
        os.environ["MKL_NUM_THREADS"] = cpu
        os.environ["NUMEXPR_NUM_THREADS"] = cpu
        os.environ["OMP_NUM_THREADS"] = cpu

select_hardware(
    cuda="3",
    cpu="4"
)

# %%
import tensorly
import tensorly as tl
tl.set_backend('pytorch')
from tensorly.decomposition import Tucker, CP, TensorTrain
from tltorch import FactorizedConv

# %%
import timm

model_name='efficientnet_b2'
# checkpoint_path=''
pretrained=True

model = timm.create_model(
    model_name,
    num_classes=1000,
    in_chans=3,
    pretrained=pretrained,
    # checkpoint_path=checkpoint_path,
)

# %%
model.cuda()
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#       (1): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#         (bn2): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): SiLU(inplace=True)
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1408, out_features=1000, bias=True)
# )

# %%
model.blocks[0][0].conv_dw
# Out:
# Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)

# %%
module = model.blocks[0][0].conv_dw
module
# Out:
# Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)

# %%
import tltorch


factorization='tucker'

decomposition_kwargs = {'init': 'random'} if factorization == 'cp' else {}
fixed_rank_modes = 'spatial' if factorization == 'tucker' else None

fact_module = tltorch.FactorizedConv.from_conv(
    module, 
    rank=0.5, 
    decompose_weights=True, 
    factorization=factorization,
    fixed_rank_modes=fixed_rank_modes,
    decomposition_kwargs=decomposition_kwargs,
    # **kwargs,
)

# %%
fact_module
# Out:
# FactorizedConv(
#   in_channels=1, out_channels=32, kernel_size=(3, 3), rank=(4, 1, 3, 3), order=2, padding=[1, 1], bias=False
#   (weight): TuckerTensor(shape=(32, 1, 3, 3), rank=(4, 1, 3, 3))
# )

# %%
import tensorly as tl 
tl.set_backend('numpy')

# %%
from tddl.factorizations import number_layers
from tddl.factorizations import factorize_network

numbered_layers = number_layers(model)
numbered_layers
# Out:
# {'conv_stem': (0,
#   Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)),
#  'bn1': (1,
#   BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#  'act1': (2, SiLU(inplace=True)),
#  'blocks': (3,
#   {'0': (4,
#     {'0': (5,
#       {'conv_dw': (6,
#         Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)),
#        'bn1': (7,
#         BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (8, SiLU(inplace=True)),
#        'se': (9,
#         {'conv_reduce': (10, Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (11, SiLU(inplace=True)),
#          'conv_expand': (12, Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (13, Sigmoid())}),
#        'conv_pw': (14,
#         Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn2': (15,
#         BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (16, Identity())}),
#      '1': (17,
#       {'conv_dw': (18,
#         Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)),
#        'bn1': (19,
#         BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (20, SiLU(inplace=True)),
#        'se': (21,
#         {'conv_reduce': (22, Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (23, SiLU(inplace=True)),
#          'conv_expand': (24, Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (25, Sigmoid())}),
#        'conv_pw': (26,
#         Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn2': (27,
#         BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (28, Identity())})}),
#    '1': (29,
#     {'0': (30,
#       {'conv_pw': (31,
#         Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (32,
#         BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (33, SiLU(inplace=True)),
#        'conv_dw': (34,
#         Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)),
#        'bn2': (35,
#         BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (36, SiLU(inplace=True)),
#        'se': (37,
#         {'conv_reduce': (38, Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (39, SiLU(inplace=True)),
#          'conv_expand': (40, Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (41, Sigmoid())}),
#        'conv_pwl': (42,
#         Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (43,
#         BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (44,
#       {'conv_pw': (45,
#         Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (46,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (47, SiLU(inplace=True)),
#        'conv_dw': (48,
#         Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)),
#        'bn2': (49,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (50, SiLU(inplace=True)),
#        'se': (51,
#         {'conv_reduce': (52,
#           Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (53, SiLU(inplace=True)),
#          'conv_expand': (54,
#           Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (55, Sigmoid())}),
#        'conv_pwl': (56,
#         Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (57,
#         BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '2': (58,
#       {'conv_pw': (59,
#         Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (60,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (61, SiLU(inplace=True)),
#        'conv_dw': (62,
#         Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)),
#        'bn2': (63,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (64, SiLU(inplace=True)),
#        'se': (65,
#         {'conv_reduce': (66,
#           Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (67, SiLU(inplace=True)),
#          'conv_expand': (68,
#           Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (69, Sigmoid())}),
#        'conv_pwl': (70,
#         Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (71,
#         BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})}),
#    '2': (72,
#     {'0': (73,
#       {'conv_pw': (74,
#         Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (75,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (76, SiLU(inplace=True)),
#        'conv_dw': (77,
#         Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)),
#        'bn2': (78,
#         BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (79, SiLU(inplace=True)),
#        'se': (80,
#         {'conv_reduce': (81,
#           Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (82, SiLU(inplace=True)),
#          'conv_expand': (83,
#           Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (84, Sigmoid())}),
#        'conv_pwl': (85,
#         Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (86,
#         BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (87,
#       {'conv_pw': (88,
#         Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (89,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (90, SiLU(inplace=True)),
#        'conv_dw': (91,
#         Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)),
#        'bn2': (92,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (93, SiLU(inplace=True)),
#        'se': (94,
#         {'conv_reduce': (95,
#           Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (96, SiLU(inplace=True)),
#          'conv_expand': (97,
#           Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (98, Sigmoid())}),
#        'conv_pwl': (99,
#         Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (100,
#         BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '2': (101,
#       {'conv_pw': (102,
#         Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (103,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (104, SiLU(inplace=True)),
#        'conv_dw': (105,
#         Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)),
#        'bn2': (106,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (107, SiLU(inplace=True)),
#        'se': (108,
#         {'conv_reduce': (109,
#           Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (110, SiLU(inplace=True)),
#          'conv_expand': (111,
#           Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (112, Sigmoid())}),
#        'conv_pwl': (113,
#         Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (114,
#         BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})}),
#    '3': (115,
#     {'0': (116,
#       {'conv_pw': (117,
#         Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (118,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (119, SiLU(inplace=True)),
#        'conv_dw': (120,
#         Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)),
#        'bn2': (121,
#         BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (122, SiLU(inplace=True)),
#        'se': (123,
#         {'conv_reduce': (124,
#           Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (125, SiLU(inplace=True)),
#          'conv_expand': (126,
#           Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (127, Sigmoid())}),
#        'conv_pwl': (128,
#         Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (129,
#         BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (130,
#       {'conv_pw': (131,
#         Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (132,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (133, SiLU(inplace=True)),
#        'conv_dw': (134,
#         Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)),
#        'bn2': (135,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (136, SiLU(inplace=True)),
#        'se': (137,
#         {'conv_reduce': (138,
#           Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (139, SiLU(inplace=True)),
#          'conv_expand': (140,
#           Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (141, Sigmoid())}),
#        'conv_pwl': (142,
#         Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (143,
#         BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '2': (144,
#       {'conv_pw': (145,
#         Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (146,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (147, SiLU(inplace=True)),
#        'conv_dw': (148,
#         Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)),
#        'bn2': (149,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (150, SiLU(inplace=True)),
#        'se': (151,
#         {'conv_reduce': (152,
#           Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (153, SiLU(inplace=True)),
#          'conv_expand': (154,
#           Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (155, Sigmoid())}),
#        'conv_pwl': (156,
#         Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (157,
#         BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '3': (158,
#       {'conv_pw': (159,
#         Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (160,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (161, SiLU(inplace=True)),
#        'conv_dw': (162,
#         Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)),
#        'bn2': (163,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (164, SiLU(inplace=True)),
#        'se': (165,
#         {'conv_reduce': (166,
#           Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (167, SiLU(inplace=True)),
#          'conv_expand': (168,
#           Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (169, Sigmoid())}),
#        'conv_pwl': (170,
#         Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (171,
#         BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})}),
#    '4': (172,
#     {'0': (173,
#       {'conv_pw': (174,
#         Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (175,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (176, SiLU(inplace=True)),
#        'conv_dw': (177,
#         Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)),
#        'bn2': (178,
#         BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (179, SiLU(inplace=True)),
#        'se': (180,
#         {'conv_reduce': (181,
#           Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (182, SiLU(inplace=True)),
#          'conv_expand': (183,
#           Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (184, Sigmoid())}),
#        'conv_pwl': (185,
#         Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (186,
#         BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (187,
#       {'conv_pw': (188,
#         Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (189,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (190, SiLU(inplace=True)),
#        'conv_dw': (191,
#         Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)),
#        'bn2': (192,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (193, SiLU(inplace=True)),
#        'se': (194,
#         {'conv_reduce': (195,
#           Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (196, SiLU(inplace=True)),
#          'conv_expand': (197,
#           Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (198, Sigmoid())}),
#        'conv_pwl': (199,
#         Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (200,
#         BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '2': (201,
#       {'conv_pw': (202,
#         Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (203,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (204, SiLU(inplace=True)),
#        'conv_dw': (205,
#         Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)),
#        'bn2': (206,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (207, SiLU(inplace=True)),
#        'se': (208,
#         {'conv_reduce': (209,
#           Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (210, SiLU(inplace=True)),
#          'conv_expand': (211,
#           Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (212, Sigmoid())}),
#        'conv_pwl': (213,
#         Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (214,
#         BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '3': (215,
#       {'conv_pw': (216,
#         Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (217,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (218, SiLU(inplace=True)),
#        'conv_dw': (219,
#         Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)),
#        'bn2': (220,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (221, SiLU(inplace=True)),
#        'se': (222,
#         {'conv_reduce': (223,
#           Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (224, SiLU(inplace=True)),
#          'conv_expand': (225,
#           Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (226, Sigmoid())}),
#        'conv_pwl': (227,
#         Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (228,
#         BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})}),
#    '5': (229,
#     {'0': (230,
#       {'conv_pw': (231,
#         Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (232,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (233, SiLU(inplace=True)),
#        'conv_dw': (234,
#         Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)),
#        'bn2': (235,
#         BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (236, SiLU(inplace=True)),
#        'se': (237,
#         {'conv_reduce': (238,
#           Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (239, SiLU(inplace=True)),
#          'conv_expand': (240,
#           Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (241, Sigmoid())}),
#        'conv_pwl': (242,
#         Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (243,
#         BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (244,
#       {'conv_pw': (245,
#         Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (246,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (247, SiLU(inplace=True)),
#        'conv_dw': (248,
#         Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)),
#        'bn2': (249,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (250, SiLU(inplace=True)),
#        'se': (251,
#         {'conv_reduce': (252,
#           Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (253, SiLU(inplace=True)),
#          'conv_expand': (254,
#           Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (255, Sigmoid())}),
#        'conv_pwl': (256,
#         Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (257,
#         BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '2': (258,
#       {'conv_pw': (259,
#         Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (260,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (261, SiLU(inplace=True)),
#        'conv_dw': (262,
#         Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)),
#        'bn2': (263,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (264, SiLU(inplace=True)),
#        'se': (265,
#         {'conv_reduce': (266,
#           Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (267, SiLU(inplace=True)),
#          'conv_expand': (268,
#           Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (269, Sigmoid())}),
#        'conv_pwl': (270,
#         Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (271,
#         BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '3': (272,
#       {'conv_pw': (273,
#         Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (274,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (275, SiLU(inplace=True)),
#        'conv_dw': (276,
#         Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)),
#        'bn2': (277,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (278, SiLU(inplace=True)),
#        'se': (279,
#         {'conv_reduce': (280,
#           Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (281, SiLU(inplace=True)),
#          'conv_expand': (282,
#           Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (283, Sigmoid())}),
#        'conv_pwl': (284,
#         Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (285,
#         BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '4': (286,
#       {'conv_pw': (287,
#         Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (288,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (289, SiLU(inplace=True)),
#        'conv_dw': (290,
#         Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)),
#        'bn2': (291,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (292, SiLU(inplace=True)),
#        'se': (293,
#         {'conv_reduce': (294,
#           Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (295, SiLU(inplace=True)),
#          'conv_expand': (296,
#           Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (297, Sigmoid())}),
#        'conv_pwl': (298,
#         Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (299,
#         BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})}),
#    '6': (300,
#     {'0': (301,
#       {'conv_pw': (302,
#         Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (303,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (304, SiLU(inplace=True)),
#        'conv_dw': (305,
#         Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)),
#        'bn2': (306,
#         BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (307, SiLU(inplace=True)),
#        'se': (308,
#         {'conv_reduce': (309,
#           Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (310, SiLU(inplace=True)),
#          'conv_expand': (311,
#           Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (312, Sigmoid())}),
#        'conv_pwl': (313,
#         Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (314,
#         BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))}),
#      '1': (315,
#       {'conv_pw': (316,
#         Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn1': (317,
#         BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act1': (318, SiLU(inplace=True)),
#        'conv_dw': (319,
#         Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)),
#        'bn2': (320,
#         BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#        'act2': (321, SiLU(inplace=True)),
#        'se': (322,
#         {'conv_reduce': (323,
#           Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))),
#          'act1': (324, SiLU(inplace=True)),
#          'conv_expand': (325,
#           Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))),
#          'gate': (326, Sigmoid())}),
#        'conv_pwl': (327,
#         Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#        'bn3': (328,
#         BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True))})})}),
#  'conv_head': (329,
#   Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)),
#  'bn2': (330,
#   BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)),
#  'act2': (331, SiLU(inplace=True)),
#  'global_pool': (332,
#   {'flatten': (333, Flatten(start_dim=1, end_dim=-1)),
#    'pool': (334, AdaptiveAvgPool2d(output_size=1))}),
#  'classifier': (335, Linear(in_features=1408, out_features=1000, bias=True))}

# %%
import copy

fact_model =  copy.deepcopy(model)

# conv_dw_by_str_layers = ['conv_dw']
# conv_dw_layers = [6, 19, 34, 48, 62, 77, 91, 105, 120, 134, 148, 162, 177, 191, 205, 219, 234, 248, 262, 276, 290, 305, 319]
conv_dw_layers = [6]

factorize_network(
    fact_model,
    layers=conv_dw_layers,
    verbose=False,
    return_error=False,
)

# %%
model
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(32, 8, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(8, 32, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(32, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#       (1): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(16, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 16, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pw): Conv2d(16, 16, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(16, 96, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(96, 4, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(4, 96, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(96, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 24, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(24, 144, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(144, 6, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(6, 144, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(144, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(288, 12, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(12, 288, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(288, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 88, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(88, 528, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(528, 22, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(22, 528, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(528, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 120, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(120, 720, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(720, 30, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(30, 720, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(720, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 208, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): Conv2d(208, 1248, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(1248, 52, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(52, 1248, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(1248, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): Conv2d(352, 2112, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#         (bn2): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): Conv2d(2112, 88, kernel_size=(1, 1), stride=(1, 1))
#           (act1): SiLU(inplace=True)
#           (conv_expand): Conv2d(88, 2112, kernel_size=(1, 1), stride=(1, 1))
#           (gate): Sigmoid()
#         )
#         (conv_pwl): Conv2d(2112, 352, kernel_size=(1, 1), stride=(1, 1), bias=False)
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): SiLU(inplace=True)
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1408, out_features=1000, bias=True)
# )

# %%
numbered_layers = number_layers(model)

# %%
tensor = tl.tensor(np.arange(24).reshape((3, 4, 2)), dtype=tl.float64)
unfolded = tl.unfold(tensor, mode=0)
tl.fold(unfolded, mode=0, shape=tensor.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-d6b679295a3e> in <module>
# ----> 1 tensor = tl.tensor(np.arange(24).reshape((3, 4, 2)), dtype=tl.float64)
#       2 unfolded = tl.unfold(tensor, mode=0)
#       3 tl.fold(unfolded, mode=0, shape=tensor.shape)
#
# AttributeError: module 'tensorly' has no attribute 'float64'

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html
#
# groups controls the connections between inputs and outputs. in_channels and out_channels must both be divisible by groups. For example,
#
# - At groups=1, all inputs are convolved to all outputs.
#
# - At groups=2, the operation becomes equivalent to having two conv layers side by side, each seeing half the input channels and producing half the output channels, and both subsequently concatenated.
#
# - At groups= in_channels, each input channel is convolved with its own set of filters (of size out_channelsin_channels\frac{\text{out\_channels}}{\text{in\_channels}}in_channelsout_channels​).

# %%
[m.numel() for m in model.conv_stem.parameters()]
# Out:
# [864]

# %%
[m.numel() for m in model.conv_head.parameters()]
# Out:
# [495616]

# %%
def listify_numbered_layers(numbered_layers, layers):
    output = []

    def parse_errors(d, layers):
        
        nonlocal output
        for k, v in d.items():
            # print(v)
            if isinstance(v[1], dict):
                parse_errors(v[1], layers)
            elif k in layers:
                output.append(
                    (
                        k, # layer_name
                        v[0], # layer_nr
                        v[1], # layer
                        # float(v[1].detach().cpu()), # approx.error wrt pretrained
                        # str(v[2]), # layer
                    )
                )
    
    parse_errors(numbered_layers, layers)
    
    return output

# %%
conv_pw_layers = listify_numbered_layers(numbered_layers, layers=['conv_pw'])
conv_pw_numbers = [x[1] for x in conv_pw_layers]
print(conv_pw_numbers)
# Out:
# [14, 26, 31, 45, 59, 74, 88, 102, 117, 131, 145, 159, 174, 188, 202, 216, 231, 245, 259, 273, 287, 302, 316]

# %%
conv_dw_layers = listify_numbered_layers(numbered_layers, layers=['conv_dw'])
conv_dw_numbers = [x[1] for x in conv_dw_layers]
print(conv_dw_numbers)
# Out:
# [6, 18, 34, 48, 62, 77, 91, 105, 120, 134, 148, 162, 177, 191, 205, 219, 234, 248, 262, 276, 290, 305, 319]

# %%
conv_reduce_layers = listify_numbered_layers(numbered_layers, layers=['conv_reduce'])
conv_reduce_numbers = [x[1] for x in conv_reduce_layers]
print(conv_reduce_numbers)
# Out:
# [10, 22, 38, 52, 66, 81, 95, 109, 124, 138, 152, 166, 181, 195, 209, 223, 238, 252, 266, 280, 294, 309, 323]

# %%
conv_expand_layers = listify_numbered_layers(numbered_layers, layers=['conv_expand'])
conv_expand_numbers = [x[1] for x in conv_expand_layers]
print(conv_expand_numbers)
# Out:
# [12, 24, 40, 54, 68, 83, 97, 111, 126, 140, 154, 168, 183, 197, 211, 225, 240, 254, 268, 282, 296, 311, 325]

# %%
conv_pwl_layers = listify_numbered_layers(numbered_layers, layers=['conv_pwl'])
conv_pwl_numbers = [x[1] for x in conv_pwl_layers]
print(conv_pwl_numbers)
# Out:
# [42, 56, 70, 85, 99, 113, 128, 142, 156, 170, 185, 199, 213, 227, 242, 256, 270, 284, 298, 313, 327]

# %%
k1x1 = conv_pwl_numbers + conv_expand_numbers + conv_reduce_numbers + conv_pw_numbers
print(k1x1)
# Out:
# [42, 56, 70, 85, 99, 113, 128, 142, 156, 170, 185, 199, 213, 227, 242, 256, 270, 284, 298, 313, 327, 12, 24, 40, 54, 68, 83, 97, 111, 126, 140, 154, 168, 183, 197, 211, 225, 240, 254, 268, 282, 296, 311, 325, 10, 22, 38, 52, 66, 81, 95, 109, 124, 138, 152, 166, 181, 195, 209, 223, 238, 252, 266, 280, 294, 309, 323, 14, 26, 31, 45, 59, 74, 88, 102, 117, 131, 145, 159, 174, 188, 202, 216, 231, 245, 259, 273, 287, 302, 316]

# %%
fact_model =  copy.deepcopy(model)

factorize_network(
    fact_model,
    layers=k1x1,
    verbose=False,
    return_error=False,
)

# %%
fact_model
# Out:
# EfficientNet(
#   (conv_stem): Conv2d(3, 32, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#   (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act1): SiLU(inplace=True)
#   (blocks): Sequential(
#     (0): Sequential(
#       (0): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(32, 32, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=32, bias=False)
#         (bn1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=32, out_channels=8, kernel_size=(1, 1), rank=(1, 4, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(8, 32, 1, 1), rank=(1, 4, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=8, out_channels=32, kernel_size=(1, 1), rank=(4, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(32, 8, 1, 1), rank=(4, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pw): FactorizedConv(
#           in_channels=32, out_channels=16, kernel_size=(1, 1), rank=(3, 6, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(16, 32, 1, 1), rank=(3, 6, 1, 1))
#         )
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#       (1): DepthwiseSeparableConv(
#         (conv_dw): Conv2d(16, 16, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=16, bias=False)
#         (bn1): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=16, out_channels=4, kernel_size=(1, 1), rank=(1, 2, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(4, 16, 1, 1), rank=(1, 2, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=4, out_channels=16, kernel_size=(1, 1), rank=(2, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(16, 4, 1, 1), rank=(2, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pw): FactorizedConv(
#           in_channels=16, out_channels=16, kernel_size=(1, 1), rank=(4, 4, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(16, 16, 1, 1), rank=(4, 4, 1, 1))
#         )
#         (bn2): BatchNorm2d(16, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): Identity()
#       )
#     )
#     (1): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=16, out_channels=96, kernel_size=(1, 1), rank=(8, 1, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(96, 16, 1, 1), rank=(8, 1, 1, 1))
#         )
#         (bn1): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(96, 96, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=96, bias=False)
#         (bn2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=96, out_channels=4, kernel_size=(1, 1), rank=(1, 2, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(4, 96, 1, 1), rank=(1, 2, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=4, out_channels=96, kernel_size=(1, 1), rank=(2, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(96, 4, 1, 1), rank=(2, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=96, out_channels=24, kernel_size=(1, 1), rank=(3, 11, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(24, 96, 1, 1), rank=(3, 11, 1, 1))
#         )
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=24, out_channels=144, kernel_size=(1, 1), rank=(12, 2, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(144, 24, 1, 1), rank=(12, 2, 1, 1))
#         )
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=144, out_channels=6, kernel_size=(1, 1), rank=(1, 3, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(6, 144, 1, 1), rank=(1, 3, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=6, out_channels=144, kernel_size=(1, 1), rank=(3, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(144, 6, 1, 1), rank=(3, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=144, out_channels=24, kernel_size=(1, 1), rank=(2, 12, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(24, 144, 1, 1), rank=(2, 12, 1, 1))
#         )
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=24, out_channels=144, kernel_size=(1, 1), rank=(12, 2, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(144, 24, 1, 1), rank=(12, 2, 1, 1))
#         )
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=144, out_channels=6, kernel_size=(1, 1), rank=(1, 3, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(6, 144, 1, 1), rank=(1, 3, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=6, out_channels=144, kernel_size=(1, 1), rank=(3, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(144, 6, 1, 1), rank=(3, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=144, out_channels=24, kernel_size=(1, 1), rank=(2, 12, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(24, 144, 1, 1), rank=(2, 12, 1, 1))
#         )
#         (bn3): BatchNorm2d(24, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (2): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=24, out_channels=144, kernel_size=(1, 1), rank=(12, 2, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(144, 24, 1, 1), rank=(12, 2, 1, 1))
#         )
#         (bn1): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(144, 144, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=144, bias=False)
#         (bn2): BatchNorm2d(144, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=144, out_channels=6, kernel_size=(1, 1), rank=(1, 3, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(6, 144, 1, 1), rank=(1, 3, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=6, out_channels=144, kernel_size=(1, 1), rank=(3, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(144, 6, 1, 1), rank=(3, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=144, out_channels=48, kernel_size=(1, 1), rank=(7, 21, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(48, 144, 1, 1), rank=(7, 21, 1, 1))
#         )
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=48, out_channels=288, kernel_size=(1, 1), rank=(23, 4, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(288, 48, 1, 1), rank=(23, 4, 1, 1))
#         )
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=288, out_channels=12, kernel_size=(1, 1), rank=(1, 6, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(12, 288, 1, 1), rank=(1, 6, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=12, out_channels=288, kernel_size=(1, 1), rank=(6, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(288, 12, 1, 1), rank=(6, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=288, out_channels=48, kernel_size=(1, 1), rank=(4, 23, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(48, 288, 1, 1), rank=(4, 23, 1, 1))
#         )
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=48, out_channels=288, kernel_size=(1, 1), rank=(23, 4, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(288, 48, 1, 1), rank=(23, 4, 1, 1))
#         )
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=288, out_channels=12, kernel_size=(1, 1), rank=(1, 6, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(12, 288, 1, 1), rank=(1, 6, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=12, out_channels=288, kernel_size=(1, 1), rank=(6, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(288, 12, 1, 1), rank=(6, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=288, out_channels=48, kernel_size=(1, 1), rank=(4, 23, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(48, 288, 1, 1), rank=(4, 23, 1, 1))
#         )
#         (bn3): BatchNorm2d(48, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (3): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=48, out_channels=288, kernel_size=(1, 1), rank=(23, 4, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(288, 48, 1, 1), rank=(23, 4, 1, 1))
#         )
#         (bn1): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(288, 288, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), groups=288, bias=False)
#         (bn2): BatchNorm2d(288, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=288, out_channels=12, kernel_size=(1, 1), rank=(1, 6, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(12, 288, 1, 1), rank=(1, 6, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=12, out_channels=288, kernel_size=(1, 1), rank=(6, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(288, 12, 1, 1), rank=(6, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=288, out_channels=88, kernel_size=(1, 1), rank=(12, 39, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(88, 288, 1, 1), rank=(12, 39, 1, 1))
#         )
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=88, out_channels=528, kernel_size=(1, 1), rank=(42, 7, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(528, 88, 1, 1), rank=(42, 7, 1, 1))
#         )
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=528, out_channels=22, kernel_size=(1, 1), rank=(1, 11, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(22, 528, 1, 1), rank=(1, 11, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=22, out_channels=528, kernel_size=(1, 1), rank=(11, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(528, 22, 1, 1), rank=(11, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=528, out_channels=88, kernel_size=(1, 1), rank=(7, 42, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(88, 528, 1, 1), rank=(7, 42, 1, 1))
#         )
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=88, out_channels=528, kernel_size=(1, 1), rank=(42, 7, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(528, 88, 1, 1), rank=(42, 7, 1, 1))
#         )
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=528, out_channels=22, kernel_size=(1, 1), rank=(1, 11, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(22, 528, 1, 1), rank=(1, 11, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=22, out_channels=528, kernel_size=(1, 1), rank=(11, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(528, 22, 1, 1), rank=(11, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=528, out_channels=88, kernel_size=(1, 1), rank=(7, 42, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(88, 528, 1, 1), rank=(7, 42, 1, 1))
#         )
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=88, out_channels=528, kernel_size=(1, 1), rank=(42, 7, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(528, 88, 1, 1), rank=(42, 7, 1, 1))
#         )
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=528, out_channels=22, kernel_size=(1, 1), rank=(1, 11, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(22, 528, 1, 1), rank=(1, 11, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=22, out_channels=528, kernel_size=(1, 1), rank=(11, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(528, 22, 1, 1), rank=(11, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=528, out_channels=88, kernel_size=(1, 1), rank=(7, 42, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(88, 528, 1, 1), rank=(7, 42, 1, 1))
#         )
#         (bn3): BatchNorm2d(88, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (4): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=88, out_channels=528, kernel_size=(1, 1), rank=(42, 7, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(528, 88, 1, 1), rank=(42, 7, 1, 1))
#         )
#         (bn1): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(528, 528, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=528, bias=False)
#         (bn2): BatchNorm2d(528, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=528, out_channels=22, kernel_size=(1, 1), rank=(1, 11, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(22, 528, 1, 1), rank=(1, 11, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=22, out_channels=528, kernel_size=(1, 1), rank=(11, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(528, 22, 1, 1), rank=(11, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=528, out_channels=120, kernel_size=(1, 1), rank=(13, 56, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(120, 528, 1, 1), rank=(13, 56, 1, 1))
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=120, out_channels=720, kernel_size=(1, 1), rank=(58, 10, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(720, 120, 1, 1), rank=(58, 10, 1, 1))
#         )
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=720, out_channels=30, kernel_size=(1, 1), rank=(1, 15, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(30, 720, 1, 1), rank=(1, 15, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=30, out_channels=720, kernel_size=(1, 1), rank=(15, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(720, 30, 1, 1), rank=(15, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=720, out_channels=120, kernel_size=(1, 1), rank=(10, 58, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(120, 720, 1, 1), rank=(10, 58, 1, 1))
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=120, out_channels=720, kernel_size=(1, 1), rank=(58, 10, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(720, 120, 1, 1), rank=(58, 10, 1, 1))
#         )
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=720, out_channels=30, kernel_size=(1, 1), rank=(1, 15, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(30, 720, 1, 1), rank=(1, 15, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=30, out_channels=720, kernel_size=(1, 1), rank=(15, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(720, 30, 1, 1), rank=(15, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=720, out_channels=120, kernel_size=(1, 1), rank=(10, 58, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(120, 720, 1, 1), rank=(10, 58, 1, 1))
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=120, out_channels=720, kernel_size=(1, 1), rank=(58, 10, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(720, 120, 1, 1), rank=(58, 10, 1, 1))
#         )
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=720, out_channels=30, kernel_size=(1, 1), rank=(1, 15, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(30, 720, 1, 1), rank=(1, 15, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=30, out_channels=720, kernel_size=(1, 1), rank=(15, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(720, 30, 1, 1), rank=(15, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=720, out_channels=120, kernel_size=(1, 1), rank=(10, 58, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(120, 720, 1, 1), rank=(10, 58, 1, 1))
#         )
#         (bn3): BatchNorm2d(120, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (5): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=120, out_channels=720, kernel_size=(1, 1), rank=(58, 10, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(720, 120, 1, 1), rank=(58, 10, 1, 1))
#         )
#         (bn1): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(720, 720, kernel_size=(5, 5), stride=(2, 2), padding=(2, 2), groups=720, bias=False)
#         (bn2): BatchNorm2d(720, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=720, out_channels=30, kernel_size=(1, 1), rank=(1, 15, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(30, 720, 1, 1), rank=(1, 15, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=30, out_channels=720, kernel_size=(1, 1), rank=(15, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(720, 30, 1, 1), rank=(15, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=720, out_channels=208, kernel_size=(1, 1), rank=(27, 93, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(208, 720, 1, 1), rank=(27, 93, 1, 1))
#         )
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=208, out_channels=1248, kernel_size=(1, 1), rank=(100, 17, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(1248, 208, 1, 1), rank=(100, 17, 1, 1))
#         )
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=1248, out_channels=52, kernel_size=(1, 1), rank=(1, 26, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(52, 1248, 1, 1), rank=(1, 26, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=52, out_channels=1248, kernel_size=(1, 1), rank=(26, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(1248, 52, 1, 1), rank=(26, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=1248, out_channels=208, kernel_size=(1, 1), rank=(17, 100, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(208, 1248, 1, 1), rank=(17, 100, 1, 1))
#         )
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (2): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=208, out_channels=1248, kernel_size=(1, 1), rank=(100, 17, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(1248, 208, 1, 1), rank=(100, 17, 1, 1))
#         )
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=1248, out_channels=52, kernel_size=(1, 1), rank=(1, 26, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(52, 1248, 1, 1), rank=(1, 26, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=52, out_channels=1248, kernel_size=(1, 1), rank=(26, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(1248, 52, 1, 1), rank=(26, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=1248, out_channels=208, kernel_size=(1, 1), rank=(17, 100, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(208, 1248, 1, 1), rank=(17, 100, 1, 1))
#         )
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (3): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=208, out_channels=1248, kernel_size=(1, 1), rank=(100, 17, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(1248, 208, 1, 1), rank=(100, 17, 1, 1))
#         )
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=1248, out_channels=52, kernel_size=(1, 1), rank=(1, 26, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(52, 1248, 1, 1), rank=(1, 26, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=52, out_channels=1248, kernel_size=(1, 1), rank=(26, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(1248, 52, 1, 1), rank=(26, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=1248, out_channels=208, kernel_size=(1, 1), rank=(17, 100, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(208, 1248, 1, 1), rank=(17, 100, 1, 1))
#         )
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (4): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=208, out_channels=1248, kernel_size=(1, 1), rank=(100, 17, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(1248, 208, 1, 1), rank=(100, 17, 1, 1))
#         )
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(5, 5), stride=(1, 1), padding=(2, 2), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=1248, out_channels=52, kernel_size=(1, 1), rank=(1, 26, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(52, 1248, 1, 1), rank=(1, 26, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=52, out_channels=1248, kernel_size=(1, 1), rank=(26, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(1248, 52, 1, 1), rank=(26, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=1248, out_channels=208, kernel_size=(1, 1), rank=(17, 100, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(208, 1248, 1, 1), rank=(17, 100, 1, 1))
#         )
#         (bn3): BatchNorm2d(208, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (6): Sequential(
#       (0): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=208, out_channels=1248, kernel_size=(1, 1), rank=(100, 17, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(1248, 208, 1, 1), rank=(100, 17, 1, 1))
#         )
#         (bn1): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(1248, 1248, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=1248, bias=False)
#         (bn2): BatchNorm2d(1248, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=1248, out_channels=52, kernel_size=(1, 1), rank=(1, 26, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(52, 1248, 1, 1), rank=(1, 26, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=52, out_channels=1248, kernel_size=(1, 1), rank=(26, 1, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(1248, 52, 1, 1), rank=(26, 1, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=1248, out_channels=352, kernel_size=(1, 1), rank=(45, 158, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(352, 1248, 1, 1), rank=(45, 158, 1, 1))
#         )
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#       (1): InvertedResidual(
#         (conv_pw): FactorizedConv(
#           in_channels=352, out_channels=2112, kernel_size=(1, 1), rank=(169, 28, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(2112, 352, 1, 1), rank=(169, 28, 1, 1))
#         )
#         (bn1): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act1): SiLU(inplace=True)
#         (conv_dw): Conv2d(2112, 2112, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), groups=2112, bias=False)
#         (bn2): BatchNorm2d(2112, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#         (act2): SiLU(inplace=True)
#         (se): SqueezeExcite(
#           (conv_reduce): FactorizedConv(
#             in_channels=2112, out_channels=88, kernel_size=(1, 1), rank=(2, 44, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(88, 2112, 1, 1), rank=(2, 44, 1, 1))
#           )
#           (act1): SiLU(inplace=True)
#           (conv_expand): FactorizedConv(
#             in_channels=88, out_channels=2112, kernel_size=(1, 1), rank=(44, 2, 1, 1), order=2,
#             (weight): TuckerTensor(shape=(2112, 88, 1, 1), rank=(44, 2, 1, 1))
#           )
#           (gate): Sigmoid()
#         )
#         (conv_pwl): FactorizedConv(
#           in_channels=2112, out_channels=352, kernel_size=(1, 1), rank=(28, 169, 1, 1), order=2, bias=False
#           (weight): TuckerTensor(shape=(352, 2112, 1, 1), rank=(28, 169, 1, 1))
#         )
#         (bn3): BatchNorm2d(352, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#   )
#   (conv_head): Conv2d(352, 1408, kernel_size=(1, 1), stride=(1, 1), bias=False)
#   (bn2): BatchNorm2d(1408, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (act2): SiLU(inplace=True)
#   (global_pool): SelectAdaptivePool2d (pool_type=avg, flatten=Flatten(start_dim=1, end_dim=-1))
#   (classifier): Linear(in_features=1408, out_features=1000, bias=True)
# )
